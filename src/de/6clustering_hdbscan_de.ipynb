# %%
# %pip install hdbscan
# Out:
# Collecting hdbscan
#   Downloading hdbscan-0.8.40-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\olive\git\eprp\.conda\lib\site-packages (from hdbscan) (2.2.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\olive\git\eprp\.conda\lib\site-packages (from hdbscan) (1.15.2)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\olive\git\eprp\.conda\lib\site-packages (from hdbscan) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\olive\git\eprp\.conda\lib\site-packages (from hdbscan) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\olive\git\eprp\.conda\lib\site-packages (from scikit-learn>=0.20->hdbscan) (3.6.0)
# Downloading hdbscan-0.8.40-cp311-cp311-win_amd64.whl (732 kB)
#    ---------------------------------------- 0.0/732.2 kB ? eta -:--:--
#    --------------------------------------- 732.2/732.2 kB 10.0 MB/s eta 0:00:00
# Installing collected packages: hdbscan
# Successfully installed hdbscan-0.8.40
# Note: you may need to restart the kernel to use updated packages.

# %%
# Daten und Vektoren
import pandas as pd
import numpy as np

# NLP & Vektoren laden
import spacy
from spacy.tokens import DocBin

# Clustering
import hdbscan
from sklearn.decomposition import PCA

# Visualisierung
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Zeichenanzahl pro Spalte erhöhen
pd.set_option("display.max_colwidth", None)

# %%
# spaCy-Modell laden
nlp = spacy.load("de_core_news_lg")

# Docs laden (wie vorher gespeichert)
doc_bin = DocBin().from_disk("docs_de.spacy")
docs = list(doc_bin.get_docs(nlp.vocab))

# DataFrame laden
df = pd.read_excel("../../data/df_de_final_duplikate_markiert.xlsx")

# %%
# Vektoren extrahieren
vectors = np.array([doc.vector for doc in docs])


from sklearn.metrics.pairwise import cosine_distances

# Cosine-Distanzmatrix erzeugen und in float64 casten
distance_matrix = cosine_distances(vectors).astype(np.float64)

# %%
# HDBSCAN mit Cosine-Distanz
clusterer = hdbscan.HDBSCAN(min_cluster_size=2, metric='precomputed')
labels = clusterer.fit_predict(distance_matrix)


# Labels ins DataFrame schreiben
df["HDBSCAN_Cluster"] = labels

# %%
print(df["HDBSCAN_Cluster"].value_counts().sort_index())
# Out:
# HDBSCAN_Cluster
# -1       1538
#  0          3
#  1          2
#  2          8
#  3         18
#          ...
#  1003      10
#  1004       3
#  1005       3
#  1006       4
#  1007       4
# Name: count, Length: 1009, dtype: int64

# %%
df[df["HDBSCAN_Cluster"] == 300][["Frage_Text"]].head(10)
# Out:
#                                                                                                                                        Frage_Text
# 3473  Sollen Kinder, die nicht Deutsch als Muttersprache haben, zuerst in separaten Klassen unterrichtet werden (vor Integration in Regelklasse)?
# 3517  Sollen Kinder, die nicht Deutsch als Muttersprache haben, zuerst in separaten Klassen unterrichtet werden (vor Integration in Regelklasse)?

# %%
df[df["HDBSCAN_Cluster"] == 27][["Frage_Typ"]].head()
# Out:
#        Frage_Typ
# 76      options4
# 4987  Standard-4
# 6537  Standard-4

# %%
df[df["HDBSCAN_Cluster"] == -1][["Frage_Text"]].head(10)
# Out:
#                                                                                                                                                                         Frage_Text
# 6                                                                   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 268  Soll sich die Stadt Luzern beim Kanton für eine Verschärfung des Sozialhilfegesetzes einsetzen (z.B. Begrenzung der Zulagen, tieferes Existenzminimum, strengere Sanktionen)?
# 271                                                                                           Befürworten Sie die Einführung eines bezahlten Vaterschaftsurlaubs von zwei Wochen?
# 279                                                                    Soll sich die Stadt Luzern stärker für Asylsuchende engagieren (bspw. im Rahmen der sog. 'Sanctuary City')?
# 282                                                                                                             Befürworten Sie eine Reduktion der städtischen Kultursubventionen?
# 283                                                                                                           Befürworten Sie eine Kürzung des Beitrags an das Luzerner Fest 2021?
# 289                                                                                 Befürworten Sie einen Einstellungsstopp für die Stadt Luzern (Einfrieren des Stellenbestands)?
# 292                                               Soll die Stadt Luzern das lokale Gewerbe stärker unterstützen (z.B. schnellere Bewilligungsverfahren, keine Parkplatzreduktion)?
# 295                                                  Soll die Stadt Luzern den Reisecar-Tourismus stärker regulieren (z.B. Einführung einer Gebühr für Halteplätze der Reisecars)?
# 299                                                                       Sollte der motorisierte Privatverkehr in der städtischen Verkehrspolitik eine höhere Priorität erhalten?

# %%
from collections import Counter

# Alle eindeutigen Cluster (ohne -1 / Noise)
cluster_ids = df["HDBSCAN_Cluster"].unique()
cluster_ids = [cid for cid in cluster_ids if cid != -1]

# Dictionary zum Speichern der Top-Wörter pro Cluster
cluster_topwörter = {}

# Für jedes Cluster: Wörter zählen & speichern
for cluster_id in cluster_ids:
    fragen = df[df["HDBSCAN_Cluster"] == cluster_id]["Frage_Text"]
    wörter = []
    
    for frage in fragen:
        doc = nlp(frage)
        for token in doc:
            if not token.is_stop and not token.is_punct and token.is_alpha:
                wörter.append(token.lemma_.lower())
    
    counter = Counter(wörter)
    häufigste = counter.most_common(10)
    # Formatieren: wort: anzahl
    cluster_topwörter[cluster_id] = ", ".join([f"{w}: {c}" for w, c in häufigste])

# Neue Spalte mit den Top-Wörtern
df["Cluster_Top_Wörter"] = df["HDBSCAN_Cluster"].apply(
    lambda cid: cluster_topwörter.get(cid, "Noise / kein Cluster")
)

# %%
df.iloc[1145]
# Out:
# ID_Wahl                                                                                                                            67.0
# Datum                                                                                                               2021-02-07 00:00:00
# Frage_ID                                                                                                                         2816.0
# Frage_Text            Soll die 30-Jahres-Frist für eine erleichterte Einbürgerung von alteingesessenen Ausländer/-innen gekürzt werden?
# Frage_Typ                                                                                                                      options4
# Bereich_ID                                                                                                                       4282.0
# Bereich                                                                                                         Migration & Integration
# ID_gesamt                                                                                                                        Q01145
# Sprache                                                                                                                              de
# Duplikat                                                                                                                          False
# Frage_Hash                                                                                             1382641769f46fe24728f939d934c5da
# Duplikat_Gruppe                                                                                                                     NaN
# HDBSCAN_Cluster                                                                                                                      -1
# Cluster_Top_Wörter                                                                                                 Noise / kein Cluster
# Name: 1145, dtype: object

# %%
# DataFrame als Excel-Datei exportieren
df.to_excel("../../data/df_de_final_duplikate_markiert_HDBSCAN.xlsx", index=False, engine="openpyxl")

# %%
df[(df["HDBSCAN_Cluster"] == -1) & (df["Duplikat"] == True)][["Frage_Text"]]
# Out:
#                                                                                                                                                                                                              Frage_Text
# 6                                                                                                        Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 462                                       Soll das Angebot im Bereich der Kinderdrittbetreuung in der Stadt Biel ausgebaut werden (Erhöhung der Krippenplätze, Verlängerung der Öffnungszeiten von Tagesschulen, usw.)?
# 526                                                                                                                                    Soll der Kanton die Lohngleichheit von Frauen und Männern stärker kontrollieren?
# 533                                                                                                        Soll der Kanton Schaffhausen das Service-Public-Angebot (z.B. ÖV-Verbindungen, Poststellen) stärker fördern?
# 534                                                       Soll der Kanton Kadermitarbeiter/-innen oder bestimmten Fachpersonen weiterhin Zulagen zahlen, um die Attraktivität des Kantons als Arbeitgeber zu steigern?
# ...                                                                                                                                                                                                                 ...
# 7436                                                                          Würden Sie der Schaffung einer kantonalen Verwaltungsstelle zur Verbesserung der Gleichstellung von Menschen mit Behinderung befürworten?
# 7439                                                   Soll der Kanton Zürich die Schaffung von familienergänzenden Betreuungsstrukturen (Tagesstätten, Tagesschulen, Mittagstische) verstärkt finanziell unterstützen?
# 7443  Würden Sie eine Verschärfung des Sozialhilfegesetzes im Kanton Zürich (z.B. Begrenzung der Zulagen, tieferer Ansatz des Existenzminimums, höherer Ermessenspielraum bei der Vergabe der Sozialhilfe) befürworten?
# 7449                                                      Sollen Landwirte, welche nicht umweltfreundlich produzieren (bspw. präventiver Einsatz von Pestiziden oder Antibiotika), keine Direktzahlungen mehr erhalten?
# 7453                                                                 Soll der Kanton Zürich Massnahmen ergreifen, um den Langsamverkehr (Velo- und Fussverkehr) gegenüber dem motorisierten Verkehr stärker zu fördern?
#
# [455 rows x 1 columns]

# %%
df[df["Duplikat_Gruppe"] == "d717627dc6d0d8b3c09432f355181f17"]
# Out:
#       ID_Wahl                Datum  Frage_ID  \
# 6         2.0  2019-10-20 00:00:00      31.0
# 361      49.0  2020-09-27 00:00:00    1388.0
# 410      18.0  2020-09-27 00:00:00    1837.0
# 456      51.0  2020-09-27 00:00:00    1633.0
# 503      20.0  2020-09-27 00:00:00    1141.0
# 551      22.0  2020-09-27 00:00:00    1902.0
# 609      24.0  2020-10-18 00:00:00    2155.0
# 670      45.0  2020-10-25 00:00:00    2335.0
# 824      32.0  2020-11-29 00:00:00    2796.0
# 872      53.0  2021-03-07 00:00:00    2989.0
# 887      55.0  2021-03-07 00:00:00    1392.0
# 974      60.0  2021-03-07 00:00:00    3260.0
# 1023     71.0  2021-04-25 00:00:00    3405.0
# 1078     63.0  2021-04-25 00:00:00    3404.0
# 1130     64.0  2021-04-25 00:00:00    3699.0
# 1179     67.0  2021-02-07 00:00:00    2850.0
# 1234     89.0  2021-11-28 00:00:00    4460.0
# 1282     75.0  2021-09-26 00:00:00    4107.0
# 1335     86.0  2021-11-28 00:00:00    4220.0
# 1501     83.0  2022-02-13 00:00:00    4868.0
# 1557     84.0  2022-02-13 00:00:00    4753.0
# 1615    103.0  2022-03-27 00:00:00    5262.0
# 1666     92.0  2022-03-27 00:00:00    5687.0
# 1773     95.0  2022-03-27 00:00:00    5793.0
# 1827    102.0  2022-02-13 00:00:00    4975.0
# 1881    105.0  2022-03-13 00:00:00    5481.0
# 1936    106.0  2022-03-13 00:00:00    5392.0
# 1988    109.0  2022-03-27 00:00:00    5632.0
# 2433    464.0  2021-03-07 00:00:00    1391.0
# 2524    482.0  2021-09-26 00:00:00    4219.0
# 2579    512.0  2022-03-13 00:00:00    5393.0
# 3749   1155.0  2025-03-02 00:00:00   33236.0
# 3797   1156.0  2025-04-13 00:00:00   33463.0
# 4859    222.0                 2019    3399.0
# 5294    255.0                 2020    4165.0
# 5693    258.0                 2020    4227.0
# 6281    222.0                 2019    3399.0
# 6583    246.0                 2020    4058.0
# 6747    284.0                 2021    4542.0
# 7193    291.0                 2021    3909.0
#
#                                                                                                            Frage_Text  \
# 6      Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 361    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 410    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 456    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 503    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 551    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 609    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 670    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 824    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 872    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 887    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 974    Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1023   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1078   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1130   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1179   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1234   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1282   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1335  Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1501   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1557   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1615   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1666   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1773   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1827   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1881   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1936   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 1988   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 2433   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 2524  Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 2579   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 3749   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 3797   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 4859   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 5294   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 5693   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 6281   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 6583   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 6747   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
# 7193   Wie beurteilen Sie diese Aussage: "Vermögende sollen sich stärker an der Finanzierung des Staates beteiligen."
#
#      Frage_Typ  Bereich_ID             Bereich ID_gesamt Sprache  Duplikat  \
# 6     options7      4734.0       Werthaltungen    Q00006      de      True
# 361   options7      4781.0       Werthaltungen    Q00361      de      True
# 410   options7      4768.0       Werthaltungen    Q00410      de      True
# 456   options7      4779.0       Werthaltungen    Q00456      de      True
# 503   options7      4756.0       Werthaltungen    Q00503      de      True
# 551   options7      4761.0       Werthaltungen    Q00551      de      True
# 609   options7      4757.0       Werthaltungen    Q00609      de      True
# 670   options7      4784.0       Werthaltungen    Q00670      de      True
# 824   options7      4760.0       Werthaltungen    Q00824      de      True
# 872   options7      4787.0       Werthaltungen    Q00872      de      True
# 887   options7      4792.0       Werthaltungen    Q00887      de      True
# 974   options7      4790.0       Werthaltungen    Q00974      de      True
# 1023  options7      4805.0       Werthaltungen    Q01023      de      True
# 1078  options7      4797.0       Werthaltungen    Q01078      de      True
# 1130  options7      4799.0       Werthaltungen    Q01130      de      True
# 1179  options7      4785.0       Werthaltungen    Q01179      de      True
# 1234  options7      4813.0       Werthaltungen    Q01234      de      True
# 1282  options7      4812.0       Werthaltungen    Q01282      de      True
# 1335  options7      4818.0       Werthaltungen    Q01335      de      True
# 1501  options7      4829.0       Werthaltungen    Q01501      de      True
# 1557  options7      4816.0       Werthaltungen    Q01557      de      True
# 1615  options7      4817.0       Werthaltungen    Q01615      de      True
# 1666  options7      4838.0       Werthaltungen    Q01666      de      True
# 1773  options7      4839.0       Werthaltungen    Q01773      de      True
# 1827  options7      4825.0       Werthaltungen    Q01827      de      True
# 1881  options7      4835.0       Werthaltungen    Q01881      de      True
# 1936  options7      4833.0       Werthaltungen    Q01936      de      True
# 1988  options7      4837.0       Werthaltungen    Q01988      de      True
# 2433  options7      4791.0       Werthaltungen    Q02433      de      True
# 2524  options7      4809.0       Werthaltungen    Q02524      de      True
# 2579  options7      4836.0       Werthaltungen    Q02579      de      True
# 3749  options7     11689.0       Werthaltungen    Q03749      de      True
# 3797  options7     11744.0       Werthaltungen    Q03797      de      True
# 4859  Slider-7         4.0  Finanzen & Steuern    Q05858      de      True
# 5294  Slider-7         4.0  Finanzen & Steuern    Q06338      de      True
# 5693  Slider-7         4.0  Finanzen & Steuern    Q06737      de      True
# 6281  Slider-7         4.0  Finanzen & Steuern    Q07605      de      True
# 6583  Slider-7         4.0  Finanzen & Steuern    Q07907      de      True
# 6747  Slider-7         4.0  Finanzen & Steuern    Q08071      de      True
# 7193  Slider-7         4.0  Finanzen & Steuern    Q08731      de      True
#
#                             Frage_Hash                   Duplikat_Gruppe  \
# 6     d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 361   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 410   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 456   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 503   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 551   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 609   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 670   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 824   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 872   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 887   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 974   d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1023  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1078  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1130  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1179  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1234  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1282  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1335  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1501  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1557  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1615  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1666  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1773  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1827  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1881  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1936  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 1988  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 2433  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 2524  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 2579  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 3749  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 3797  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 4859  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 5294  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 5693  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 6281  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 6583  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 6747  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
# 7193  d717627dc6d0d8b3c09432f355181f17  d717627dc6d0d8b3c09432f355181f17
#
#       HDBSCAN_Cluster  \
# 6                  -1
# 361               250
# 410               250
# 456               250
# 503               251
# 551               251
# 609               251
# 670               247
# 824               247
# 872               247
# 887               247
# 974               250
# 1023              250
# 1078              247
# 1130              250
# 1179              250
# 1234              246
# 1282              250
# 1335              250
# 1501              250
# 1557              246
# 1615              246
# 1666              246
# 1773              246
# 1827              250
# 1881              250
# 1936              250
# 1988              250
# 2433              246
# 2524              250
# 2579              246
# 3749              250
# 3797              250
# 4859              250
# 5294              250
# 5693              246
# 6281              246
# 6583              246
# 6747              250
# 7193              246
#
#                                                                                        Cluster_Top_Wörter
# 6                                                                                    Noise / kein Cluster
# 361   beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 410   beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 456   beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 503          beurteilen: 3, aussage: 3, vermögende: 3, stark: 3, finanzierung: 3, staat: 3, beteiligen: 3
# 551          beurteilen: 3, aussage: 3, vermögende: 3, stark: 3, finanzierung: 3, staat: 3, beteiligen: 3
# 609          beurteilen: 3, aussage: 3, vermögende: 3, stark: 3, finanzierung: 3, staat: 3, beteiligen: 3
# 670          beurteilen: 5, aussage: 5, vermögende: 5, stark: 5, finanzierung: 5, staat: 5, beteiligen: 5
# 824          beurteilen: 5, aussage: 5, vermögende: 5, stark: 5, finanzierung: 5, staat: 5, beteiligen: 5
# 872          beurteilen: 5, aussage: 5, vermögende: 5, stark: 5, finanzierung: 5, staat: 5, beteiligen: 5
# 887          beurteilen: 5, aussage: 5, vermögende: 5, stark: 5, finanzierung: 5, staat: 5, beteiligen: 5
# 974   beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1023  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1078         beurteilen: 5, aussage: 5, vermögende: 5, stark: 5, finanzierung: 5, staat: 5, beteiligen: 5
# 1130  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1179  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1234  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 1282  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1335  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1501  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1557  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 1615  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 1666  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 1773  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 1827  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1881  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1936  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 1988  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 2433  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 2524  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 2579  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 3749  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 3797  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 4859  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 5294  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 5693  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 6281  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 6583  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
# 6747  beurteilen: 21, aussage: 21, vermögende: 21, stark: 21, finanzierung: 21, staat: 21, beteiligen: 21
# 7193  beurteilen: 11, aussage: 11, vermögende: 11, stark: 11, finanzierung: 11, staat: 11, beteiligen: 11
